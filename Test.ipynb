# %% [markdown]
# # **VZ Intern Hackathon**

# %%
# import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from geopy.geocoders import Nominatim
import folium

# initialize Nominatim (which means “name” in Latin) as a variable called geolocator => uses OpenStreetMap data to match addresses with geopgraphic coordinates
geolocator = Nominatim(user_agent = "Mapping App", timeout = 2)

# read in datasets
customer_df = pd.read_csv("potentialCustomers.csv")
customer_df

antenna_df = pd.read_csv("possibleAntennaLocations.csv")
antenna_df
# Out:
#      Location Code                             Address        LAT       LONG
# 0              A-1    12 Brayton Rd Scarsdale NY 10583  41.014263 -73.788063
# 1              A-2    8 Berkeley Rd Scarsdale NY 10583  41.015926 -73.786278
# 2              A-3     3 Berwick Rd Scarsdale NY 10583  40.999424 -73.797485
# 3              A-4  101 Brewster Rd Scarsdale NY 10583  41.006466 -73.787865
# 4              A-5    1 Berkeley Rd Scarsdale NY 10583  41.016464 -73.787254
# ...            ...                                 ...        ...        ...
# 1572        A-1573     81 Brite Ave Scarsdale NY 10583  41.004482 -73.792915
# 1573        A-1574     82 Brite Ave Scarsdale NY 10583  41.004730 -73.792732
# 1574        A-1575        17 Oak Ln Scarsdale NY 10583  41.005318 -73.794418
# 1575        A-1576     6 Olmsted Rd Scarsdale NY 10583  41.001507 -73.798607
# 1576        A-1577   7 Parkfield Rd Scarsdale NY 10583  41.004322 -73.799057
#
# [1577 rows x 4 columns]

# %%
# mapping and visualizing customer addresses
def create_map_markers(row, map_name):
    #folium.Marker(location=[row['LAT'], row['LONG']], icon = folium.Icon(color = "pink", icon = "fa-solid fa-house", prefix='fa'), popup = row['Address']).add_to(map_name)
    folium.Rectangle([(row['LAT'], row['LONG'])], popup = row['Address']).add_to(map_name)
    
scarsdale_map = folium.Map(location=[41.008, -73.791214], zoom_start = 13.5)
scarsdale_map

customer_df.apply(create_map_markers, map_name = scarsdale_map, axis = 'columns')
scarsdale_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e492912ab6d456113148a7ba35cf8c62 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e492912ab6d456113148a7ba35cf8c62&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e492912ab6d456113148a7ba35cf8c62 = L.map(
#                 &quot;map_e492912ab6d456113148a7ba35cf8c62&quot;,
#                 {
#                     center: [41.008, -73.791214],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ff2929721f1870a787d8414836fa5ba1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e492912ab6d456113148a7ba35cf8c62);
#
#
#             var rectangle_c17a1fa137539f7ef1954031d25419b9 = L.rectangle(
#                 [[41.01395035, -73.78813171]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e492912ab6d456113148a7ba35cf8c62);
#
#
#         var popup_a17ae7dd7970b02ac200feb7606eb143 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c8d48ca0cd07a643b7d063751de4132f = $(`&lt;div id=&quot;html_c8d48ca0cd07a643b7d063751de4132f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;12 Brayton Rd Scarsdale NY 10583&lt;/div&gt;`)[0];
#                 popup_a17ae7dd7970b02ac200feb7606eb143.setContent(html_c8d48ca0cd07a643b7d063751de4132f);
#
#
#
#         rectangle_c17a1fa137539f7ef1954031d25419b9.bindPopup(popup_a17ae7dd7970b02ac200feb7606eb143)
#         ;
#
#
#
#
#             var rectangle_0ea246e595c39cf27286d7a146a400b1 = L.rectangle(
#                 [[41.01567459, -73.7864151]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e492912ab6d456113148a7ba35cf8c62);
#
#
#         var popup_ebe46785dc75bf852f7fcdbc38170f14 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5ba065c42bc5eb75470a6dc5681ee15a = $(`&lt;div id=&quot;html_5ba065c42bc5eb75470a6dc5681ee15a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;8 Berkeley Rd Scarsdale NY 10583&lt;/div&gt;`)[0];
#                 popup_ebe46785dc75bf852f7fcdbc38170f14.setContent(html_5ba065c42bc5eb75470a6dc5681ee15a);
#
#
#
#         rectangle_0ea246e595c39cf27286d7a146a400b1.bindPopup(popup_ebe46785dc75bf852f7fcdbc38170f14)
#         ;
#
#
#
#
#             var rectangle_edc442bdb41c07eeb3bb306f06dfb2f8 = L.rectangle(
#                 [[40.99957657, -73.79780579]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e492912ab6d456113148a7ba35cf8c62);
#
#
#         var popup_bfd04b857238e613c430194a100c702f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ef11d3811083240e1b5d163504c0fb81 = $(`&lt;div id=&quot;html_ef11d3811083240e1b5d163504c0fb81&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3 Berwick Rd Scarsdale NY 10583&lt;/div&gt;`)[0];
#                 popup_bfd04b857238e613c430194a100c702f.setContent(html_ef11d3811083240e1b5d163504c0fb81);
#
#
#
#         rectangle_edc442bdb41c07eeb3bb306f06dfb2f8.bindPopup(popup_bfd04b857238e613c430194a100c702f)
#         ;
#
#
#
#
#             var rectangle_484851929152c41019d65c5b7b1f8787 = L.rectangle(
#                 [[41.00653076, -73.78809357]],
